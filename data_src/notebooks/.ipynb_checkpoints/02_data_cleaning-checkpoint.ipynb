# %%
import pandas as pd
import numpy as np
import os

# %%
#Neither the mobile app can't deal with big files, neither pandas can't open such massive loads. 
#100000.
raw_foods = pd.read_csv("../landing_zone/foods.csv", delimiter = '\t', dtype=str, nrows = 100000)

# %%
#make imported file as DataFrame
df_raw_foods = pd.DataFrame(raw_foods)

# %%
df_raw_foods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Columns: 186 entries, code to carnitine_100g
# dtypes: object(186)
# memory usage: 141.9+ MB

# %%
drop_unwanted_columns = df_raw_foods.drop(['url',
                'code',                           
                'creator',
                'created_t',
                'created_datetime',
                'last_modified_t',
                'last_modified_datetime',
                'abbreviated_product_name',
                'generic_name',
                'packaging',
                'packaging_tags',
                'packaging_text',
                'brands',
                'brands_tags',
                'categories',
                'categories_tags',
                'origins',
                'origins_tags',
                'origins_en',
                'manufacturing_places',
                'manufacturing_places_tags',
                'labels',
                'labels_tags',
                'labels_en',
                'emb_codes',
                'emb_codes_tags',
                'cities',
                'cities_tags',
                'purchase_places',
                'stores',
                'ingredients_text',
                'allergens',
                'allergens_en',
                'traces',
                'traces_tags',
                'traces_en',
                'no_nutriments',
                'additives_n',
                'additives_tags',
                'additives_en',
                'additives',
               # 'ingredients_that_may_be_from_palm_oil_n',
               # 'ingredients_that_may_be_from_palm_oil',
               # 'ingredients_that_may_be_from_palm_oil_tags',
               # 'ingredients_from_palm_oil_n',
               #  'ingredients_from_palm_oil',
               # 'ingredients_from_palm_oil_tags',
                'states_en',
                'states_tags',
                'states',
                'brand_owner',
                'main_category',
                'image_url',
                'image_small_url',
                'image_nutrition_url',
                'image_nutrition_small_url',
                'image_ingredients_url',
                'image_ingredients_small_url',
                '-butyric-acid_100g',
                '-caproic-acid_100g',
                '-caprylic-acid_100g',
                '-capric-acid_100g',
                '-lauric-acid_100g',
                '-myristic-acid_100g',
                '-palmitic-acid_100g',
                '-stearic-acid_100g',
                '-arachidic-acid_100g',
                '-behenic-acid_100g',
                '-lignoceric-acid_100g',
                '-cerotic-acid_100g',
                '-montanic-acid_100g',
                '-melissic-acid_100g',
                '-alpha-linolenic-acid_100g',
                '-eicosapentaenoic-acid_100g',
                '-docosahexaenoic-acid_100g',
                '-linoleic-acid_100g',
                '-arachidonic-acid_100g',
                '-gamma-linolenic-acid_100g',
                '-oleic-acid_100g',
                '-gondoic-acid_100g',
                '-mead-acid_100g',
                '-erucic-acid_100g',
                '-nervonic-acid_100g',
                '-dihomo-gamma-linolenic-acid_100g',
                '-elaidic-acid_100g',
                'starch_100g',
                'polyols_100g',
                '-maltodextrins_100g',
                #'-soluble-fiber_100g',
                #'-insoluble-fiber_100g',
                'casein_100g',
                'serum-proteins_100g',
                'nucleotides_100g',
                'beta-carotene_100g',
                'folates_100g',
                'biotin_100g',
                'pantothenic-acid_100g',
                'bicarbonate_100g',
                'silica_100g',
                'chloride_100g',
                'copper_100g',
                'fluoride_100g',
                'chromium_100g',
                'selenium_100g',
                'molybdenum_100g',
                'fruits-vegetables-nuts_100g',
                'fruits-vegetables-nuts-dried_100g',
                'fruits-vegetables-nuts-estimate_100g',
                'collagen-meat-protein-ratio_100g',
                'cocoa_100g',
                'chlorophyl_100g',
                'taurine_100g',
                'carbon-footprint_100g',
                'carbon-footprint-from-meat-or-fish_100g',
                'trans-fat_100g',
                'nutrition-score-fr_100g',
                'nutrition-score-uk_100g',
                'glycemic-index_100g',
                'choline_100g',
                'phylloquinone_100g',
                'beta-glucan_100g',
                'inositol_100g',
                'carnitine_100g',
                'monounsaturated-fat_100g',
                'polyunsaturated-fat_100g',
                '-sucrose_100g',
                'pnns_groups_1',
                'pnns_groups_2',
                '-maltose_100g',
                'first_packaging_code_geo',
                'serving_size',
                'serving_quantity',
                'nova_group',
                'vitamin-pp_100g',
                'energy-from-fat_100g',
                'energy-kj_100g',
                'energy_100g',
                'quantity',
                'categories_en',
                'nutriscore_score',
               # 'ecoscore_score_fr',
               # 'ecoscore_grade_fr',
                'omega-9-fat_100g',
                '-lactose_100g',
                '-glucose_100g',
                '-fructose_100g',
                'water-hardness_100g',
                'omega-6-fat_100g',
                'caffeine_100g',
                'iron_100g',
                'manganese_100g',
                'phosphorus_100g',
                'alcohol_100g',
                'omega-3-fat_100g',
                'magnesium_100g',
                'iodine_100g',
                'zinc_100g',
                'calcium_100g',
                'potassium_100g',
                'vitamin-a_100g',
                'vitamin-b1_100g',
                'vitamin-c_100g',
                'vitamin-b12_100g',
                'vitamin-d_100g',
                'vitamin-e_100g',
                'vitamin-k_100g',
                'vitamin-b2_100g',
                'vitamin-b6_100g',
                'vitamin-b9_100g',
                'sodium_100g',
                'ph_100g',
                'cholesterol_100g',
                'countries',
                'countries_tags',
                'salt_100g',
                'fiber_100g',
                'sugars_100g', 
                'ingredients_tags',
                'packaging_en',
                'food_groups',
                'food_groups_tags',
                'food_groups_en',
                'ecoscore_grade',
                'ecoscore_score',
                'saturated-fat_100g',
                'insoluble-fiber_100g',
                'fruits-vegetables-nuts-estimate-from-ingredients_100g',
                'soluble-fiber_100g',
                'main_category_en'], axis = 1) # axis 0 = rows , axis 1 = columns

# %%
drop_unwanted_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_name        98214 non-null  object
#  1   countries_en        99853 non-null  object
#  2   nutriscore_grade    56828 non-null  object
#  3   energy-kcal_100g    91506 non-null  object
#  4   fat_100g            91695 non-null  object
#  5   carbohydrates_100g  91737 non-null  object
#  6   proteins_100g       91681 non-null  object
# dtypes: object(7)
# memory usage: 5.3+ MB

# %%
#filter None values on product_name
clean_product_name = drop_unwanted_columns.dropna(subset=['product_name'])
clean_product_name['product_name'].unique().tolist()
# Out:
# ['jeunes pousses',
#  'L.casei',
#  'Vitória crackers',
#  'Cacao',
#  'Filetes de pollo empanado',
#  'Hamburguesas de ternera 100%',
#  'hyde icon',
#  ' moutarde au moût de raisin ',
#  'Sauce Sweety chili 0%',
#  'Mini coco',
#  "Pistou d'ail des ours",
#  'Pain maïs',
#  'Mendiants',
#  'Limonade artisanale a la rose',
#  'Sachet calisson',
#  'Pur jus de pomme',
#  "Pate d'amande",
#  'Salade de carottes râpées',
#  'Fromage blanc aux myrtilles',
#  'Vainilla',
#  'Iogurt de cabra',
#  'Baguette parisien',
#  'Chocolate n 3',
#  '&quot;Baguette Lyonnais&quot;',
#  'Solène céréales poulet',
#  'Tarte noix de coco',
#  'Caramel au beurre salé',
#  'Salade de fruits exotiques',
#  'Chouquettes x 30',
#  'Pain de maïs bio',
#  'Tisane Cassis',
#  'Fromage blanc pêche',
#  'Crème dessert chocolat',
#  'Bouillie de sarrasin',
#  'Yaourt au chocolat',
#  'Compote de poire',
#  'Paëlla de poulet',
#  'Aiguillettes de poulet',
#  'Salade shaker chef',
#  'Salade de macedoine de légumes',
#  'Baguette Poitevin',
#  'Suedois thon',
#  'Ciabatta Bombay',
#  'Ciabatta Roma',
#  'Confiture de lait',
#  'Salade tomate',
#  'Farine de blé noir',
#  'Sel du Chateau',
#  'Mousse chocolat douceur',
#  'Baguette bio au levain',
#  'Coca des flandres',
#  'Brochettes dinde',
#  'Suedois saumon',
#  'Saucisse au chou fumé BBC SV (Morteau)',
#  'Jus de Pommes',
#  'Crêpes au Kamok',
#  'Caramel vanille',
#  'Thé blanc de la Reunion',
#  'Salade shaker taboulé',
#  'Banana Chips Sweetened (Whole)',
#  'Peanuts',
#  'Sandwich classique fromage',
#  'Pain epeautre',
#  'Sandiwch Tradition Complet Jambon',
#  'Fromage blanc à la creme de marron',
#  "Nectar d'abricot",
#  'Abondance',
#  'Salade verte',
#  'cuisse de poulet direct au four curry',
#  'Bagel',
#  'Sandwich solene céréales sicilien',
#  'Brioché poulet caesar',
#  'BAguette bressan',
#  'Baguette Niçois',
#  'Pavé de saumon fumé à la ficelle',
#  'Torti au saumon fumé',
#  'CORNED BEEF',
#  'Le rogallais chèvre brebis',
#  'Miel de thym',
#  'Mediterranean Pasta Salad',
#  'Monbana',
#  'Le Jardin des simples',
#  'pavé de saumon fumé',
#  'Fromage blanc fermier de chèvre au lait entier',
#  'Pain fit n fiz',
#  'Thé Oolong Violette',
#  'Salade fusili poulet curry',
#  'Baguette Lyonnais &quot;Petit prix&quot;',
#  'Galettes Bretonnes 300gr - Biscuiterie &quot;le phare&quot;',
#  'Miel de printemps',
#  'Sommeil Bio',
#  'Pasta box carbonara',
#  'Pasta box jambon champignion',
#  'Salade Grecque',
#  'Salade penne pesto',
#  'Rillettes de sanglier au Chouchen',
#  'Bagel Boston',
#  'Tarte chocolat',
#  'Soupe aux légumes de mon jardin',
#  'Céleri remoulade',
#  'Puntazos',
#  'Suédois Jambon',
#  'Salade fraîcheur 3 fromages',
#  'Salade fraicheur caesar',
#  'salade ibérique',
#  'Pâte de fruit fraise',
#  'Bretzels en chocolat au lait',
#  'Solène céréales deux fromages',
#  'Confiture artisanale de Raphaël',
#  '8 Buchettes poulet cœur aux figues',
#  'Baguette Gruyère &quot;Petit Prix&quot;',
#  'Salade primeur',
#  'Organic Salted Nut Mix',
#  'Organic Polenta',
#  'Breadshop Honey Gone Nuts Granola',
#  'Organic Long Grain White Rice',
#  'Organic Muesli',
#  'Organic Dark Chocolate Minis',
#  'Organic Sunflower Oil',
#  'Organic Adzuki Beans',
#  'Organic Penne Pasta',
#  'Rillettes de boeuf poivre/piment',
#  'Zen Party Mix',
#  'Organic Golden Flax Seeds',
#  'Organic Spicy Punks',
#  'Biscuit du bourg de batz',
#  'Biscuits du Bourg de Batz',
#  'Mélange fruits secs',
#  'Cinnamon Nut Granola',
#  'Organic Hazelnuts',
#  'Organic Sweetened Banana Chips',
#  'Lotus Organic Brown Jasmine Rice',
#  'Organic Oat Groats',
#  'Energy Power Mix',
#  'Antioxidant Mix - Berries & Chocolate',
#  'Organic Quinoa Coconut Granola With Mango',
#  'Fire Roasted Hatch Green Chile Almonds',
#  'Peanut Butter Power Chews',
#  'Real Salt Granular',
#  'Organic Unswt Berry Coconut Granola',
#  'Farine semi-complète type 80',
#  'Roasted Salted Black Pepper Cashews',
#  'Thai Curry Roasted Cashews',
#  'Wasabi Tamari Almonds',
#  'Organic Medium Shredded Coconut',
#  'Organic Red Quinoa',
#  'Dark Chocolate Coconut Chews',
#  'Seventh Heaven Organic Trail Mix',
#  'Organic Unsweetened Granola, Cinnamon Almond',
#  'Organic Blueberry Almond Granola',
#  'Sweeteners, Demerara Turbinado Sugar',
#  "Aunt Maple's Crunchy Granola",
#  'Organic Coconut Chips',
#  'Organic Black Beans',
#  'Organic Whole Grain Emmer Farro',
#  'Organic Hard Red Wheat Berries',
#  "Aunt Ginger's Snappy Granola",
#  'Dark Chocolate Sea Salt & Turbinado Almonds',
#  'Divinely Organic Granola',
#  'Organic Black Chia Seeds',
#  'Crème de marrons d Ardèche',
#  'Naturablue original',
#  'Cotelettes',
#  'Ciao le sel! Iodé',
#  'Les délices de la Monne',
#  'Rillettes de canard au foie gras',
#  'boulanger',
#  'Habitus Stimulus',
#  'Filet de bœuf',
#  'Crema di nocciola',
#  'Mon jus de pomme',
#  'Marks % Spencer 2 Blueberry Muffins',
#  'Pâte a tartiner',
#  'Organic French Green Lentils',
#  'Naturakrill',
#  'Organic Garbanzo Beans',
#  'Organic Green Split Peas',
#  'Organic Small Red Chili Beans',
#  'Organic Small White Beans',
#  'Organic Grey-Green Lentils',
#  'Organic Yellow Split Peas',
#  'Organic Mung Beans',
#  'Organic Baby Lima Beans',
#  'Organic Dark Red Kidney Bean',
#  'Coconut Almond Granola',
#  'Moelleux au chocolat',
#  'Tarte flan',
#  'Maple Almond Granola',
#  '35% Fruit And Fiber Muesli',
#  'Rebel Crunch Granola',
#  'Organic Mixed Vegetable Spirals',
#  'Tricolor Tortellini',
#  'Organic Couscous',
#  'Organic Spaghetti',
#  'Orzo Rosa Marina',
#  'Organic Refined Spelt Flour',
#  '10-Grain Pancake Mix',
#  'Fine Sea Salt',
#  'Sweeteners, Organic Fair Trade Sugar',
#  'Organic Refined Unbleached White Flour',
#  'Organic Whole Brown Rice Flour',
#  'Organic Whole Spelt Flour',
#  'Organic Whole Rye Flour',
#  'Granola Cranberry And Acai',
#  'Organic Medium Whole Wheat Flour',
#  'Organic Soft Whole Wheat Pastry Flour',
#  'Peanuts, Mixed Nuts',
#  'Mousse au chocolat',
#  'Organic Large Raw Whole Cashews',
#  'Organic Brown Sesame Seeds',
#  'Organic White Sesame Seeds',
#  'Almonds Hickory-Smoked',
#  'Foods, Spanish Peanuts',
#  'Foods, Honey Roasted Nut Mix',
#  'Roasted Salted Sunflower Seeds',
#  'Foods, Deluxe Nut Mix',
#  'Foods, Honey Roast Nuts & Fruit Mix',
#  'Organic Raw Walnuts',
#  'Organic Raw Sunflower Seeds',
#  'Organic Trail Mix',
#  'Organic Pecan Halves',
#  'Unsalted Dry Roasted Almonds',
#  'Fromage blanc à la crème de marron',
#  'Organic Extra Virgin Olive Oil',
#  'Liquid Aminos',
#  'Organic Canola Oil Refined',
#  'Organic Shoyu',
#  'Organic Wheat-Free Tamari',
#  'Organic Grade B Maple Syrup',
#  'Curry Lentil Soup Mix',
#  'Split Pea Soup Mix',
#  "Whole Wheat 'N Honey Fig Bars",
#  'Chocolate Nut Crunch',
#  'Lion Peanut x2',
#  'Milk Chocolate Peanut Butter Malt Balls',
#  'Organic Tamari Pumpkin Seed',
#  'Gateaux bretons',
#  'Yogurt Pretzels',
#  'Courge spaghetti au bleu',
#  'Organic Kamut Flakes',
#  'Regular Rolled Oats',
#  'Quick Rolled Oats',
#  'Organic Bulgur',
#  'Organic Toasted Buckwheat Groats',
#  'Organic Rolled Barley Flakes',
#  'Multigrain Cereal Flakes',
#  '8-Grain Wheat Free Cereal',
#  'Swiss-Style Muesli',
#  'Organic Hulless Barley',
#  'Organic Millet',
#  'Organic Popcorn',
#  'Organic Soft White Wheat Berries',
#  'Organic Pearled Barley',
#  'Organic Wheat Bran',
#  'Organic Raw Buckwheat Groats',
#  'Organic Oat Bran',
#  'Organic Thick Cut Rolled Oats',
#  'Organic Regular Rolled Oats',
#  'Moelleux',
#  'Organic Steel-Cut Oats',
#  'Organic Spelt Berries',
#  'Organic Quick Rolled Oats',
#  'Countrywild Rice Blend',
#  'Organic Arboria Rice',
#  'Lundberg Organic Golden Rose Medium Brown Rice',
#  'Twix x2',
#  'Lundberg Olde World Pilaf',
#  'Galets chocolat lait',
#  'Pack de 2 Twix',
#  'Organic Short Grain Brown Rice',
#  'Organic Sweet Brown Rice',
#  'Organic California White Sushi Rice',
#  'Organic Harvest Pilaf',
#  'Organic Wild Rice',
#  'Vanilla Extract',
#  'Poulet roti',
#  'Organic Flax Seed',
#  'Cranberries',
#  'Rémi',
#  'Turkish Apricots',
#  'Banana Chips Sweetened',
#  'Granola Honey Almonds',
#  'Chili Mango',
#  'Milk Chocolate Pretzels',
#  'M&S Extrenely Chocolatey Milk, Dark & White Chocolate Biscuits',
#  "Mont d'Or",
#  "Nut'Alsace",
#  'herta',
#  "diet lemonade by Sainsbury's",
#  'Organic Salted Pistachios',
#  'Organic Dried Turkish Apricots, Bin # 5801',
#  'Organic Unsalted Pistachios',
#  'Organic Medjool Dates',
#  'Organic Pitted Prunes',
#  'Organic Pitted Deglet Dates',
#  'Sweetened Dried Cranberries',
#  'Organic Zante Currants',
#  'Organic Thompson Raisins',
#  'Organic Unrefined Extra Virgin Coconut Oil',
#  'Organic Brown Basmati Rice',
#  'Organic White Basmati Rice',
#  'Organic Unrefined Mascobado Sugar',
#  'Organic U.S. Peanuts',
#  'Almonds',
#  'Pecan Halves',
#  'Organic Whole Cashews',
#  'Organic Pearl Quinoa',
#  "Chataignes d'aiguefonfe",
#  'La jausiereine',
#  'Fresh Organic Carrots',
#  'BreadAhead Doughnuts',
#  'Thé des mamans',
#  'Preparation en poudre pour biscuit Genoise',
#  'Décors a parsemer',
#  'Paleta gran reserva - Sierra nevada-',
#  'Billes en chocolat',
#  'Stylo glaçage gris',
#  'Barre chocolat au lait praliné',
#  'Paupière de saumon et st jacques',
#  'Miel',
#  "Miel Corse BIO maquis d'été",
#  'Barbe à papa',
#  'Mini muffins fourrés caramel 8+4GRT',
#  'Biscuit tigre bio',
#  'Paris Brest chocolat',
#  "Huile d'olive de Nîmes vierge extra",
#  "McDonald's",
#  'Rite start kids & teens',
#  'I ghjorni di biscotti',
#  'Pop corn caramel',
#  'Blanquette de Volaille et son Riz',
#  'Raviolini au Fromage de chèvre et Pesto',
#  'Potage instantané champignon',
#  'Salade Cesar',
#  'Le Craquant au Pineau des Charentes',
#  'Alo Exposed',
#  "Huile d'olive persil ail",
#  'BERLINGOTS saveur caramel',
#  'Tarta San Marcos',
#  'Broyé de la grande Aquitaine aux noix du sud-ouest',
#  'Croc salé',
#  '15 petites galettes',
#  'Bon bombz jelly',
#  'Pop corn chocolat',
#  'Huile d’olives basilic ail',
#  "Huile d'olive vierge extra cuve magali",
#  'Tarta fresa',
#  'Danoises à la cannelle roulées',
#  "Comme j'aime",
#  'Thé louis xiv',
#  'Miel de lavande',
#  'potage instantané tomate basilic',
#  'Rucher du domaine national de chambord',
#  'Entremets Crème Brulée',
#  'Potage instantané 8 légumes',
#  'petits légumes sauce provençale et riz',
#  'Lote jamón gran reserva navidul',
#  'Riz au lait',
#  'Bonbon fourres',
#  'Pechuga de pavo braseada',
#  "Sel aromatisé d'après Apicius",
#  'Veggie Colin the Caterpillar',
#  'Dragées aux amandes',
#  'Dragee d amande',
#  'Huile olives thym romarin',
#  'Flute',
#  'Test',
#  'Feta and slow roasted tomato pasta',
#  'Confiture extra de pêche blanche',
#  'still Scottish water',
#  'barretta con cioccolato fondente e riso',
#  'Fairtrade Ground Cinnamon',
#  'Bonne maman pâte à tartiner noisettes et cacao',
#  'Dragé Coeurs de chocolat argenté',
#  'Chaussons tressés aux pommes',
#  'Yaourt myrtille',
#  'Yaourt caramel beurre salé',
#  'Sucettes Fer de Lance',
#  'Dragées',
#  'Jus de Pomme',
#  'Dessert lacte',
#  'Ratatouille Bio',
#  'Croccante con pistacchi e miele',
#  'PAIN EPAUTRE BIO',
#  'ficelle au saumon',
#  'Coeurs chocolat tte couleur',
#  'Mini cuchaule au beurre',
#  'Pavé jocondien',
#  "Reese's Peanut Butter Cups",
#  'Les confiotes de mamie',
#  'Coeur de chocolat etui',
#  'Pizza prosciutto',
#  'Tarte au Maroilles',
#  'Dragées Amandes Avola blanche',
#  'Pain Burger Artisan',
#  'Fiocchi di riso',
#  'Acqua alla mandorla',
#  'Katsuobushi (Dried and smoked bonito flakes)',
#  'Organic pesto alla genovese',
#  'Organic vegan pesto',
#  'Organic pesto with Tofu',
#  'pesto',
#  'Organic black olives cream',
#  "Crème d'Artichaut Bio Kazidomi",
#  'Organic walnut cream',
#  'Pesto Rosso',
#  'Pain de mie sans gluten',
#  'Crème glacée noisette',
#  'lentilles vertes ',
#  'Mangues séchées',
#  'Abricots',
#  'Oeufs',
#  'Root Beer',
#  "Jus d'orange 33cl",
#  'Palets au beurre',
#  'Sables a la noix de coco',
#  'Biscuits sablés fourrage au cacao',
#  'A&w - Root Beer - 355ml',
#  'Bratwurst moving mountains',
#  'Nerds',
#  'Quiche Lorraine',
#  'Pâté au poulet',
#  'Miel de Lavande',
#  'free',
#  'Fèves de cacao',
#  'Compote de Pomme',
#  'Bonbons acidulés Raisin Fraise',
#  'Papas en Hojuelas',
#  'Beinscheiben',
#  'Chocolat de couverture noir',
#  'Chocolat de couverture lait',
#  'Chocolat de couverture blanc',
#  'Thé noir aromatisé violette et fleurs',
#  'The noir aromatisé fruits rouges',
#  'Thé noir aromatisé vanille-chocolat',
#  'Thé de Noël aromatisé orange-cannelle',
#  'Colorant alimentaire',
#  'Pépite de chocolat blanc',
#  'Sirops pour ganache macarons',
#  'Feutre alimentaire noir',
#  'Colorant alimentaire rouge',
#  'Glaçage fondant',
#  "Pate d'amandes",
#  "Pâte d'Amandes",
#  'Stylo déco rouge sang',
#  'Preparation mug cake chocolat-caramel au beurre salé',
#  'Maïs popcorn',
#  'Mini Confettis',
#  'Pâte à sucre rouge',
#  'Colorant Alimentaire Rouge velours en spray',
#  'Colorant alimentaire velour marron',
#  'Colorant alimentaire bleu velours en spray',
#  'Pâte à Sucre',
#  'Praliné Amande Et Noisette',
#  'Œuf chocolat lait praliné',
#  'Stylo glaçage blanc',
#  'Stylo glacage',
#  'Stylo glaçage rose',
#  'Stylo glaçage bleu',
#  'Spray Alimentaire Paillette Dorees',
#  'Alice Délice pépites chocolat lait',
#  'Pâte à sucre',
#  'Pâte à sucre orange',
#  'Pate a sucre',
#  'Pate a sucre Alice Delice',
#  'Décors sucrés',
#  'Décros sucrés',
#  'Preparation biscuits nature',
#  'Preparation biscuits cacao/noisette',
#  'CHOCOLAT LAIT 50%',
#  'Chocolat lait noisette',
#  'Chocolat noir Irish whisky',
#  'Pop corn',
#  'Pâte à tartiner Lait Noisette Pétillant',
#  'Pâte à tartiner Noir noisettes pistache',
#  'Multigrain Ciabatta Buns',
#  'Fondant au chocolat',
#  'Carrot cake',
#  'Crêpes maison',
#  'blabblub',
#  'Crackers ai cereali antichi',
#  'Jambon de porc Manex',
#  'Brioches roulées avec raisins',
#  'Chocolat noir amandes caramelisées',
#  'เล็บมือนาง (ตีนไก่ )',
#  'Df',
#  'Kochspeck',
#  'Confiture de fraise mara des bois',
#  'Hot Dog Relish',
#  'Madagascar Bourbon Pure Vanilla Extract',
#  'Pan',
#  'Cassoulet à la graisse d’oie',
#  'Dattes Mejdoul',
#  'Biscuits',
#  'Chocolat',
#  'Tripoux',
#  'Hachis parmentier',
#  'Confiture pommes-mûres',
#  'Côtes du Rhône Villages 2014',
#  'Butter Croissants',
#  'Wild Blueberry Muffins',
#  'Bolillos',
#  'Biscuit',
#  'Oatmeal Raisin Cookie',
#  'Sliced Plain Bagel',
#  'Scone',
#  'Belgian Vanilla Waffle',
#  'Seasonal Cookie Platter',
#  'Muffin',
#  'Freshly Baked Italian Loaf',
#  'Freshly Baked Apple Pie',
#  'Snickerdoodle Cookies',
#  'Freshly Baked In Store Cherry Turnover',
#  'Apple Turnover',
#  'Pineapple Coconut Muffins',
#  'Assorted Strudel Bite',
#  'Freshly Baked Chocolat Croissant',
#  'Cornbread',
#  'La Brea Bakery Ciabatta Loaf Freshly Baked In Store',
#  'Al-Seedawi',
#  'Crema de leche',
#  'Renuvo',
#  'Zumo de Piña',
#  'Clyde and the caterpillar cake',
#  'Belgische Pralinen',
#  'Belgian Choc Chip Waffle',
#  'Chocolate Scone',
#  'Foie gras de canard entier du sud-ouest',
#  "Jus d'orange 25cl",
#  'Riso rosso',
#  'Confiture de fraises et griottes',
#  'Boule de pain',
#  'Boule tranchée',
#  'Pain complet tranché',
#  'PAIN AU SON',
#  'Pain de mie',
#  'Gros pain',
#  'Couronne des rois',
#  'Baguette Cereale',
#  'Donuts fourrage vanille',
#  'Pain seigle',
#  'Eclairs choco X2',
#  'Pain',
#  'Baguette',
#  "Donut's nature sucre",
#  'Pâre à tartiner noisettes et cacao',
#  "mini doony's chocolat x8",
#  'Maxi pain au chocolat',
#  "Bun's",
#  'hrenovka za pečenje na žaru hofer',
#  'Clémentines',
#  'Nuez chilena',
#  'PAINS CHOCO AOP X 5',
#  'Torsade chocolat x4',
#  'Plain bagels',
#  'Crêpe fabrication maison',
#  'Luxury Christmas Pudding',
#  'Pain aux noix',
#  'Schoko Duo',
#  'Kartoffelpüree (zubereitet)',
#  'Mendiants - Studentenhaver',
#  'Jus de pomme',
#  'From.fond.ste Creme 23%MG',
#  'Pastille Vichy',
#  'Tisane nerf - sommeil',
#  'Critical hash',
#  'Tisana',
#  'Noix du Brésil',
#  'Kitkat White Wafers',
#  "Reese's sticks",
#  'Big cup',
#  "Cookies 'n' creme",
#  "Reese's",
#  'Thé vert s’enchaîne bio',
#  "Reese's 2 Peanut Butter Cups",
#  'Crousti de volaille bio',
#  'Céleri Rémoulade',
#  'Queso cabra',
#  'Physalis',
#  'Fettarme rote Griller',
#  '2 no chicken kievs',
#  'Lapin en morceaux',
#  'Croissant',
#  '37CL Cornichons Aigre Doux Kuhne',
#  'Cornichons Aigres-doux Recette Paysanne - Kûhn',
#  'Cornichons à La Russe Kühne 970 G (530 G égoutté)',
#  "M&M's Peanut Butter",
#  'Francais',
#  'Pepsi, Nouveau goût !',
#  'Milky Way Simply Caramel',
#  'Pain mais et graines de tournesol',
#  'Jamon gran reserva',
#  'Pain fantaisie',
#  'Fuzetea schwarzer Tee Zitrone',
#  'Fuzetea schwarzer Tee Pfirsich',
#  'Madalena de Almendra',
#  'supa',
#  'Melange de noix - Nuts mix 500 gr',
#  'Heinz Firecracker Sauce 220Ml',
#  'Salad cream',
#  'Heinz Squeeze Sauce Salade Cream',
#  'Ginger Extra Jam',
#  'Fine Cut Marmelade - L. Roses & Co LTD - 454G',
#  "Duerr's Marmelade Morceaux Fins Orange",
#  "Marmelade classique a l'orange",
#  'Naturally Flavored Beverage Enhancer With Other Natural Flavors',
#  'Heinz Burger Sauce 220Ml',
#  'Sauce Sandwich Spread',
#  'Pot 100G Moutarde Anglaise Colman',
#  'HALLS Extra Strong',
#  'Natural Honey Wildflower',
#  'Amandes',
#  'Coca Cola',
#  'Diet Coke',
#  'Blle Pet 50CL Coca Cola Cherry',
#  'Figues séchées',
#  'Nuggets de volaille bio',
#  'Mix Energie Superfood',
#  'mini mints',
#  'Couscous Complet',
#  'Chips de banane',
#  'Amandes enrobées de chocolat',
#  'Risotto royal',
#  "Flocons d'epeautre",
#  'Flocons quatre graines',
#  'Monuka honig',
#  'Granola Agave & Miel',
#  'Schwarzwälder Schinken',
#  'Becks blue',
#  'Coeurs coulants au chocolat',
#  'Biscuits avoine choco',
#  'Lomo ibérico de bellota',
#  'Paupiettes de chou',
#  'Seelachsfilet (Köhler)',
#  'Pavés de saumon, nature',
#  'Galette de Pommes de Terre',
#  'Knuper crusties',
#  'Bunte Früchteauslese',
#  'Pudding-Schnecken',
#  'Poêlée de riz et saumon sauvage',
#  'Chicken Chips',
#  'Bruschetta Pomodoro',
#  'Frühlingsrollen',
#  'Marillenknödel',
#  'Dorade-sébaste meunière',
#  'Riesensadwich',
#  'Bo loempias',
#  'BoFrost Nudelpfanne',
#  'Asiapfanne xian style',
#  'Lasagnes aux saumon et aux épinards',
#  'Gaufres de Bruxelles',
#  'Pâte feuilletée',
#  'Brochettes de poulet Hawaï',
#  'Loop fries',
#  "Tartines À L'italienne",
#  'Crêpes jambon fromage',
#  'Nems de poulet',
#  "Boulettes au boeuf charolais et à l'oignon",
#  'Foie de veau coupe bouchère',
#  'Épaule de porcelet rôtie',
#  'Aiguillettes de poulet marinées',
#  'Pomme dauphine',
#  'Gratin Dauphinois',
#  'Purée de potiron et oignons rissolés',
#  'Soupe au potiron et éclats de châtaignes',
#  'Velouté aux petits pois et lardons',
#  'Fondants aux courgettes',
#  'Charlottes à la forestiere',
#  'Poêlée cuisinée aux asperges',
#  'Babas au rhum',
#  'Bûche roulée Élégance',
#  "Beignet légumes d'aubergines",
#  'Cordonbleu',
#  'Bofrost Free Tortelli Ricotta',
#  'Petits pains aux graines sans gluten et sans lactose',
#  'Free',
#  'Persil',
#  'Plantes aromatiques méditerranéennes',
#  'Nacho nuss-nougat',
#  'Cordon Bleu vom Schwein',
#  'Chicken Wings',
#  'Fausse limande du Pacifique dans une panire aux céréales',
#  'Tartelettes au saumon',
#  'Petits pains complets aux graines',
#  'Big Choco Framboise',
#  'Tarte saumon épinards',
#  'Tarte Poireaux Et Lardons',
#  'Tarte à la provençale et chèvre',
#  'Muffins apéritifs bloc de foie gras et figue',
#  'Taboulé de petit épeautre',
#  'Panier noix de saint Jacques',
#  'Panier chèvre épinards',
#  'Tresses de volaille à la forestière',
#  'Tartes fines Saint Jacques et poireaux',
#  'Coquilles Saint-Jacques Nantaises',
#  'Coquilles st Jacques prestige',
#  'Coquille crevettes et boursin',
#  'Food balls italia',
#  'Food balls',
#  "Food'balls",
#  'Poelee du dauphine',
#  'Cannellonis a la bolognaise',
#  'Quenelles de brochet sauce Nantua',
#  "Polenta ball's à poêler",
#  'Medaillon de porcelet',
#  'Cuisses de poulet',
#  'Crêpes bretonnes façon tatin',
#  'Tarte aux abricots',
#  'Pasteis de nata',
#  'Rhum Caramargue  à la fleur de sel',
#  'Pommes cannelle séchées',
#  'Chicken Nachos',
#  'Mini cheese',
#  'Hershey s milk nuggets',
#  'Salami',
#  'Sol',
#  'Cauliflower',
#  'Cordon bleu de volaille bio',
#  'Wild about Nerds',
#  'B. slim',
#  'Acqua oligominerale San benedetto frizzante',
#  'Nutella',
#  'Bresaola',
#  "Huile d'olive vierge extra",
#  'Thick Rolled Oats',
#  'Green Lentils',
#  'Cookie vegan',
#  'Petit hoppelli noir',
#  'Pain spécial maïs tournesol campanière',
#  'Danonino',
#  'Salsa de mostaza',
#  'Ajoarriero',
#  'Marmite Original Pate A Tartiner 125G',
#  'Tomato Ketchup Heinz Ouverture En Bas',
#  'Tomato Ketchup',
#  '7Up',
#  'Yaourt vanille',
#  'Pavé du Larzac',
#  'Miel de Pays (Fleurs)',
#  'Barritas vegetales ecológicas',
#  'Horseradish cream',
#  'Pavé Multicéréales',
#  'Gusanitos',
#  'Caña lomo bellota ibérica',
#  'Bûche la forêt noire',
#  'Pain aux 2 lins',
#  'Testartikel',
#  'Madeleines nature',
#  'Pepites de cuchaule',
#  'Confiture de gratte-cul',
#  'Donut Milka',
#  'Véritable pâte à tartiner noisettes chocolat noir',
#  'Mix moderne de Noël blanc et or',
#  'Confiture de  chataigne Bio',
#  'Poutargue de mulet sous vide',
#  'Poutargue de mulet',
#  'Cardon au naturel',
#  'Rillettes de truite de Bordeaux au citron confit',
#  'Poulet epicé',
#  "Lagg's, chamomile herbal tea",
#  "Lagg's, herbal tea, peppermint",
#  'Linden Flowers Tea',
#  'Herbal Tea, Hibiscus',
#  'Apple & Cinnamon Tea',
#  "Lagg's, green tea",
#  "Lagg's, shave grass herbal tea",
#  "Lagg's, herbal tea, chamomile * mint",
#  'Artichoke Herbal Tea',
#  "Lagg's, dieter's herbal tea",
#  "Lagg's, kidneytea, herbal tea",
#  "Lagg's, bronchtea",
#  'Miel de Garrigues',
#  'Oatmeal chocolate chip cookies',
#  'Bread',
#  'Kefir blueberry',
#  'Probiotic keifer smoothie',
#  'Kefir Strawberry',
#  'Farmer cheese',
#  'Delice caramel',
#  'Sucre neige',
#  'Bio Pain Ardennais',
#  'benecalorie calorie and food enhancer',
#  '100% Pure Canola Oil',
#  'Original Buttery Spread',
#  'Canola harvest, buttery spread, with flaxseed oil',
#  'Born fruta fresca deshidratada',
#  'Potager Malin - Potiron et Vermicelles',
#  "PurSoup' - Velouté de Potiron",
#  'Snacks de mais',
#  'Baka food',
#  'Pain riz chateigne',
#  'Cacao con Avellana',
#  'خبز شرائح ابيض متوسط',
#  'Talon de jambon',
#  'German fine bread',
#  "Today's temptations, lithuanian rye bread",
#  'Mousse al Cioccolato',
#  'Escalope de dinde',
#  'Pain au chocolat pur beurre x10',
#  'Harvest whole wheat bread',
#  "Mel de l'avi Joan",
#  'Croissant pur beurre',
#  'Chocolat artisanal noir',
#  'Spring Onions',
#  'Croissants pure beure',
#  'Yaourt brasse aux fruits',
#  'Madeleine Framboise',
#  'Miel de fleurs',
#  'Croissants margarine',
#  'Croissant pur beurre x8',
#  'Pain au chocolat pur beurre',
#  'Beignet chocolat',
#  'Madeleines ChocoLait',
#  'Seitán a la plancha',
#  'San Francisco style sourdough bread',
#  'Mini chaussons à la compote de pomme',
#  'Pains aux raisins',
#  'Foglia di loto',
#  'Celebrations, candy',
#  'Milkyway, magic stars chocolates',
#  "Pruneau d'agen",
#  'Geovision',
#  'Suisse longue aux pépites de chocolat x2',
#  'Agua mineral natural.',
#  'Cravate crème pâtissière',
#  'Torsadées au pépites de chocolat Intermarché',
#  'Chouquettes Intermarché &quot;moche&quot;',
#  "Mcvitie's, digestives cheesecake, lemon",
#  "Mcvitie's, mini gingerbread men, milk chocolate",
#  'butifarra blanca',
#  'Glaces vegetales des alpes',
#  'Pâté de chevreuil',
#  'Poichinade curry',
#  "P'tits beignets parfum choco-noisette",
#  'Bizcocho de chocolate',
#  'Ketchup Amora',
#  '4 Beignets parfum chocolat-noisette *4',
#  'Beignet parfum Choco noisette',
#  'Organic Flourless Sprouted 7-Grain Bread',
#  '4 beignets à la pomme',
#  'Jamon',
#  'Beignets chocolats noisettes decongelé',
#  'Vanilla Peaches',
#  'COCO by Angela',
#  'Beignets à la pomme',
#  'Barretta proteica',
#  'Gaufres traditionelles',
#  'Puppodums',
#  'Cracked Wheat Sourdough Bread',
#  'Bohnen grün lang',
#  'Madeleines Choco Noir',
#  'Mousse au chocolat noir',
#  'Filet de colin sauce dieppoise, riz et jardinière de légumes',
#  'Carottes',
#  'Mehrkomponeneten Protein 90 C6 Haselnuß',
#  'La meule',
#  'Tetley, black tea',
#  'The simpsons donuts',
#  'Tortitas de trigo- Roti wraps',
#  'Salmone Affumicato',
#  'Nadalin',
#  'Tamarin confit piment',
#  'Mini viennoiserie',
#  'Farandole de madeleine',
#  'Brasato al vino rosso',
#  'Monterey Jack',
#  'Roasted Peanuts',
#  'Terrine de campagne',
#  'Frukt rod',
#  'Croissants pur beurre',
#  'Bakers Best, White Bread',
#  'Bakers Best, Rye Bread',
#  'Eclairs Campagniere',
#  'Udon',
#  'Beignets gourmands parfum choco-noisettes',
#  'Religieuse au chocolat',
#  'Piñon nacional',
#  'Mehrkomponeneten Protein 90 C6 Banane',
#  'Leffe',
#  'Peach',
#  'Salambo au kirsh',
#  'Lomo ibérico de Bellota',
#  "Confit d'Oignons ou de figues",
#  'bizcocho',
#  'Dictator',
#  'Quatre quarts au pomme',
#  'Colomba all’Albicocca',
#  'Vitello tonnato',
#  'Gnocchetti alla romana',
#  'Tiramisu',
#  'Lasaña de espinacas',
#  'Bagietka duża 370g',
#  'Warner Hudson, Whisky Chocolates',
#  'Piasten, Chocolate Assortment',
#  "Pâté a l'ail",
#  'Nois de cajou crues',
#  'Flat Leaf Parsley',
#  'Fruits delight',
#  'Bio Casein Protein neutral',
#  "Confiture d'oranges",
#  'Flan',
#  'Filet de poulet extra tendre thym citron',
#  'Nestle, dark truffles grand chocolate',
#  'Saucisses de poulet saveur aux herbes',
#  'Chicken kievs',
#  'CARCADET',
#  "Mt. olive, sweet 'n' hot salad peppers",
#  "Big Papa's, Southern Sauce",
#  'Cakes aux Fruits',
#  'Chair à saucisse',
#  'Lomo de bellota  ibérico 50% raza ibérica',
#  'Tarte normande',
#  'Donuts Simpson Fraise',
#  'Superfruit Muesli',
#  'Sweet Envy',
#  "Atwood's Ranch Dressing",
#  'Banana bread',
#  'Strolghino di prosciutto',
#  'bijou',
#  'Burger di zucca con cicoria',
#  'Cool mint flavor dental gum, cool mint',
#  'Dental gum',
#  'Pumpkin seeds',
#  'Tarte feuilletée vergeoise aux poires',
#  'Fromage de chèvre à la ferme',
#  'Madeleines',
#  'Brownies',
#  'Pure Whey Protein Berries & Cream',
#  'Pure Whey Protein™ Chocolate Peanut',
#  'Organic Ashwagandha KSM-66',
#  'Chaource lait cru',
#  'Gefilte Fish',
#  'Confit noisettes au miel',
#  'Ritter sport, knusperflakes mit knusprigen cornflakes',
#  'Rum Trauben Nuss, Milk Chocolate Wih Rum Raisins & Nuts',
#  'Bacon de dos assaisonné',
#  'Milk Chocolate With Caramelized Almonds',
#  'Madeleine nature et choconoir',
#  'Bizcochada',
#  'Chorizo Bellota',
#  'Pan de agua',
#  'Confiture de noix',
#  'Funsch, High Quality Marzipan',
#  'Oatmeal Raisin Cookies',
#  'The Best Peanut Butter Cookies',
#  'The best chocolate chip cookies in the world',
#  'Best Sweet-Potato Cookies',
#  'Best Ginger Snap Cookies',
#  'Formula 1 nutrional shake mix',
#  'smelties',
#  'Lactaid, ice cream, vanilla',
#  'Natural ice cream',
#  'Lactaid, ice cream, butter pecan',
#  'Olive all ascolana al tartufo',
#  'Weizenmehl',
#  'Teriyaki butter and sugar snap peas seafood',
#  'Spaghetti Zurück zum Ursprung',
#  'Pollo al curry con basmati e cipolla caramellata',
#  'Pure Whey Protéine',
#  '100% Soja Protein Haselnuss',
#  'Confirure de fruits rouges',
#  'Decoupe de poulet façon chorizo',
#  'Whey Protein aus Molke Vanilla',
#  "piadina romagnola alla riminese all'olio extra vergine di oliva",
#  'Alice im Beerenland',
#  'SDW Tradution complet thon',
#  'Magdalenas mini clasicas',
#  'Bizcocho choco chips',
#  'Miel du Marais Poitevin',
#  'Purition',
#  'Strawberries',
#  'Post Workout',
#  'Financiers aux Amandes',
#  'Organic tomato pulp',
#  'organic tomato pasre',
#  'Organic tomato sauce with basil',
#  'ORGANIC TOMATO SAUCE ARRABIATA',
#  'Tomato sauce with eggplants',
#  'Sauce Tomate Aux Champignons Bio Kazidomi',
#  'Sauce Tomate Puttanesca Bio Kazidomi',
#  'Sauce Tomate Aux Courgettes Bio Kazidomi',
#  'Sauce Tomate Au Thon & Olives Bio Kazidomi',
#  'Organic tomato sauce bolognese',
#  'Pain coupiagaise',
#  'Whey Protein aus Molke 1000 Gramm Vanilla',
#  'Sauce tomate aux légumes bio Kazidomi',
#  'Passata de tomates bio',
#  'Krainer poco piccante',
#  'Pain platine',
#  'Pavé Complet',
#  'Chipolatas',
#  'Organic tomato sauce arrabiata',
#  'Croutons',
#  'Baguette constance',
#  'Fondants Citron',
#  'L’authentique pain paillasse cereales',
#  'Beignets fourres au chocolat',
#  'Mini beignets assortis',
#  'Escalopes de dinde milanaise (chapelure nature)',
#  'Organic coconut palm sugar',
#  ...]

# %%
#filter None values on countries_en
clean_countries = clean_product_name.dropna(subset=['countries_en'])
clean_countries['countries_en'].unique().tolist()
# Out:
# ['France',
#  'Spain',
#  'United States',
#  'Ireland',
#  'Belgium',
#  'United Kingdom',
#  'France,United States',
#  "Côte d'Ivoire",
#  'Canada',
#  'Switzerland',
#  'Italy',
#  'Germany',
#  'Belgium,France',
#  'Peru',
#  'Oman',
#  'Slovenia',
#  'France,Germany',
#  'France,Germany,Netherlands',
#  'United Arab Emirates',
#  'France,Switzerland',
#  'India',
#  'Romania',
#  'Australia',
#  'Germany,Spain',
#  'Luxembourg',
#  'Mexico',
#  'Dominican Republic',
#  'Réunion',
#  'Puerto Rico',
#  'Saudi Arabia',
#  'Poland',
#  'Portugal',
#  'Germany,United States',
#  'Germany,Ireland',
#  'Bulgaria',
#  'Rwanda',
#  'Netherlands',
#  'France,United Kingdom',
#  'Belgium,France,Netherlands,United Kingdom',
#  'Guadeloupe',
#  'Chile',
#  'Thailand',
#  'El Salvador',
#  'Spain,Switzerland',
#  'France,Russia',
#  'Hungary',
#  'France,India',
#  'Austria,Frankreich,Spanien',
#  'Senegal',
#  'United Kingdom,United States',
#  'Andorra',
#  'European Union',
#  'Austria,France',
#  'Luxembourg,Deutschland,Spanien',
#  'Russia',
#  'Panama',
#  'Jersey',
#  'France,Hungary,United Kingdom',
#  'Czech Republic,France',
#  'Gibraltar',
#  'France,Germany,Spain',
#  'Belgium,Germany',
#  'Hong Kong',
#  'France,Spain',
#  'Mauritius',
#  'Singapore,Spain,United States',
#  'Ethiopia',
#  'Costa Rica',
#  'Canada,United States',
#  'Qatar',
#  'Austria,France,Germany',
#  'Mexico,United States',
#  'Ecuador',
#  'Israel',
#  'Australia,France',
#  'France,Switzerland,United States',
#  'Kuwait',
#  'Honduras',
#  'French Polynesia',
#  'Sweden',
#  'France,Spain,United States',
#  'Canada,Switzerland,United States',
#  'France,Thailand',
#  'Guernsey',
#  'Germany,Luxembourg',
#  'France,Ireland',
#  'France,Gabon',
#  'Bulgaria,Cyprus,France,Germany,Italy,Poland',
#  'Morocco',
#  'Germany,Malaysia',
#  'Argentina',
#  'Guam',
#  'French Polynesia,United States',
#  'Egypt,United States',
#  'Belgium,United States',
#  'Spain,United States',
#  'Monaco',
#  'Croatia',
#  'Canada,France',
#  'Egypt',
#  'Switzerland,United States',
#  'Virgin Islands of the United States',
#  'Palestinian territories',
#  'Germany,Ireland,United States',
#  'Pakistan',
#  'Saint Pierre and Miquelon',
#  'Canada,Switzerland',
#  'Somalia',
#  'Haiti',
#  'Chile,China,Peru,Puerto Rico',
#  'Singapore',
#  'France,Réunion',
#  'Greece',
#  'Taiwan',
#  'Australia,Belgium,France,Germany,Luxembourg,Switzerland',
#  'Argentina,France,United States',
#  'France,Germany,Morocco',
#  'Brazil',
#  'Belgium,Spain',
#  'Norway',
#  'Bermuda',
#  'France,Morocco',
#  'Guatemala',
#  'Australia,France,New Zealand',
#  'Australia,United States',
#  'Pakistan,Saudi Arabia',
#  'France,Iraq',
#  'Jamaica',
#  'Algeria',
#  'Jordan',
#  'Bahrain',
#  'New Zealand',
#  'Philippines',
#  'Indonesia',
#  'Colombia',
#  'Malaysia',
#  'Costa Rica,United States',
#  'Moldova,United States',
#  'Czech Republic,France,United States',
#  'Belgium,France,United States',
#  'France,Iraq,United States',
#  'New Caledonia',
#  'Martinique',
#  'France,New Caledonia',
#  'Saudi Arabia,United States',
#  'Finland',
#  'Aruba',
#  'Czech Republic',
#  'Australia,France,Sweden,United States',
#  'Sweden,United States',
#  'Austria,Germany,Sweden,United Kingdom,United States',
#  'Uzbekistan',
#  'En-us',
#  'Niger',
#  'France,French Polynesia',
#  'Vietnam',
#  'Martinique,United States',
#  'France,United Kingdom,United States',
#  'Austria,United States',
#  'Austria,France,United States',
#  'France,Mexico,United States',
#  'France,Spain,Switzerland',
#  'France,Switzerland,United Kingdom',
#  'France,French Polynesia,United States',
#  'France,Ireland,United Kingdom',
#  'Spain,United Kingdom',
#  'Maldives',
#  'Suriname',
#  'France,Mexico',
#  'France,Guadeloupe',
#  'Netherlands,United Kingdom',
#  'Sint Maarten',
#  'Australia,New Zealand,Singapore,Thailand,United States',
#  'Italy,Switzerland',
#  'France,Spain,United Kingdom',
#  'Australia,France,United States',
#  'China,United States',
#  'Saint Lucia,United States',
#  'Lebanon',
#  'Puerto Rico,United States',
#  'India,Spain,United States',
#  'Colombia,Spain',
#  'Lebanon,United States',
#  'Trinidad and Tobago',
#  'Iceland',
#  'Venezuela',
#  'United Arab Emirates,United States',
#  'United States,France-united-states',
#  'France,New Caledonia,United States',
#  'France,Germany,United States',
#  'New Caledonia,United States',
#  'France,Israel',
#  'France,Panama',
#  'France-united-states',
#  'France,Panama,United States',
#  'Brazil,United Kingdom',
#  'France,Germany,Switzerland',
#  'Costa Rica,Mexico,Spain,Estados-unidos',
#  'Mexico,Thailand,United States,Francia',
#  'Isle of Man',
#  'Australia,Canada,France',
#  'France,Germany,Russia,United Kingdom,United States',
#  'Netherlands,United States',
#  'France,Netherlands',
#  'France,Norway,Spain',
#  'Norway,Spain',
#  'France,Norway',
#  'France,Germany,Switzerland,United States',
#  'The Bahamas',
#  'Malaysia,United States',
#  'Brazil,United States',
#  'France,Germany,United Kingdom',
#  'France,Sweden,United States',
#  'Iraq',
#  'Kenya',
#  'Austria',
#  'Mongolia',
#  'Guadeloupe,United States',
#  'Mexico,United States,Francia',
#  'Barbados',
#  'Belize',
#  'Mexico,Spain',
#  'Guinea',
#  'France,Hong Kong',
#  'Antigua and Barbuda',
#  'China',
#  'Ghana',
#  'Mayotte',
#  'Seychelles',
#  'Saint Martin',
#  'Thailand,United States',
#  'China,Hong Kong',
#  'Chile,United States',
#  'France,United States,Allemagne,Royaume-uni',
#  'Saint Lucia',
#  'Niger,United States',
#  'Kuwait,Spain,Francia',
#  'Ukraine,United States',
#  'Cameroon',
#  'Republic-of-macedonia',
#  'Canada,France,Germany',
#  'France,Luxembourg',
#  'France,Lebanon',
#  'Saint Vincent and the Grenadines',
#  'Ireland,United Kingdom',
#  'Nigeria',
#  'Georgia',
#  'En-en-united-kingdom',
#  'Canada,Italy',
#  'Saint Martin,United States',
#  'Germany,Japan,Switzerland,United States',
#  'Finland,Germany,Netherlands',
#  'Belgium,France,Switzerland,United States',
#  'Germany,Switzerland,United States',
#  'Belgium,Denmark,France,Germany,Spain,United States',
#  'Belgium,Netherlands,United States',
#  'Belgium,France,Germany,Switzerland,United Kingdom',
#  'Belgium,France,Germany',
#  'Belgium,France,Germany,Italy',
#  'Belgium,Switzerland',
#  'Belgium,France,Germany,Spain,Switzerland',
#  'Germany,United Kingdom',
#  'Belgium,France,Spain',
#  'Hong Kong,United States',
#  'France,Guyana,United States',
#  'France,Italy',
#  'France,Germany,Mexico,Sweden,Switzerland,United States',
#  'France,Hungary,Spain,United States',
#  'Japan',
#  'South Korea',
#  'Northern Mariana Islands',
#  'Canada,Mexico',
#  'United States,Etats-unis',
#  'Anguilla',
#  'Serbia',
#  'France,Martinique',
#  'Germany,Spain,United States',
#  'Barbados,France,Spain,United States',
#  'Canada,France,United States',
#  'France,Ireland,United States',
#  'Philippines,United States',
#  'Panama,United States',
#  'Germany,Mexico,United States',
#  'New Caledonia,Singapore',
#  'Hong Kong,Singapore',
#  'France,French Polynesia,Taiwan',
#  'France,Saint Kitts and Nevis',
#  'Etats-unis',
#  'Brazil,France',
#  'Libya',
#  'Haiti,United States',
#  'El Salvador,France',
#  'Jamaica,United States',
#  'Bahrain,United States',
#  'Japan,United States',
#  'France,Germany,Spain,United States',
#  'Dominican Republic,United States',
#  'France,Italy,Spain,United States',
#  'Guatemala,United States',
#  'Switzerland,United Kingdom',
#  'Germany,Switzerland',
#  'Myanmar',
#  'Colombia,France,United States',
#  'France,Taiwan,United States',
#  'Australia,New Zealand',
#  'European Union,United Kingdom',
#  'Kyrgyzstan',
#  'European Union,France',
#  'Afghanistan',
#  'France,Oman',
#  'Canada,Hong Kong,United States',
#  'Trinidad and Tobago,United States',
#  'Guyana',
#  'Caribbean Netherlands',
#  'Francia-espana',
#  'San Marino',
#  'France,Greece',
#  'France,United Arab Emirates',
#  'Spain,Francia',
#  'North-carolina',
#  'Jersey,United Kingdom',
#  'Cuba',
#  'Italy,United States',
#  'France,Kuwait',
#  'Austria,France,French Polynesia,Netherlands,Switzerland',
#  'France,Italy,United States',
#  'Palau',
#  'Germany,Philippines',
#  'France,Germany,United Kingdom,United States',
#  'France,Mexico,Spain,United States',
#  'France,Mexico,Spain',
#  'France,Thailand,United Kingdom',
#  'France,Netherlands,United Kingdom',
#  'France,Germany,Hong Kong,United States',
#  'Israel,United States',
#  'Bolivia,France,United States',
#  'France,Puerto Rico,United States',
#  'Kuwait,United States',
#  'Paraguay',
#  'Bolivia',
#  'Turkey,United States',
#  'France,United Arab Emirates,United States',
#  'Sint Maarten,United States',
#  'Anguilla,United States',
#  'El Salvador,Mexico,United States',
#  'Dominican Republic,Spain',
#  'France,Hong Kong,Singapore',
#  'France,Israel,Mexico',
#  'United States,En',
#  'France,Germany,Poland,Switzerland',
#  'Austria,France,Germany,Spain',
#  'France,Germany,Switzerland,United States,En',
#  'Myanmar,United States',
#  'France,Italy,United Kingdom',
#  'France,Germany,Italy,Switzerland,United States',
#  'Mali',
#  'France,Spain,Switzerland,United States',
#  'Belgium,France,Switzerland,United Kingdom,United States',
#  'France,Switzerland,United Kingdom,United States']

# %%
#replace null values on nutriscore_grade
clean_nutriscore_grade = clean_countries.dropna(subset=['nutriscore_grade'])

# %%
#replace null values by zer0

clean_energy_kcal_100g = clean_nutriscore_grade.dropna(subset=['energy-kcal_100g'])

clean_fat_100g = clean_energy_kcal_100g.fillna({'fat_100g': 0})

clean_carbohydrates_100g = clean_fat_100g.fillna({'carbohydrates_100g': 0})

clean_proteins_100g = clean_carbohydrates_100g.fillna({'proteins_100g': 0})

# %%
#filter for the localization supported in the utFoods app

filter_pt  =  clean_proteins_100g[clean_proteins_100g.countries_en == 'Portugal'] 
filter_es  =  clean_proteins_100g[clean_proteins_100g.countries_en == 'Spain'] 
filter_fr  =  clean_proteins_100g[clean_proteins_100g.countries_en == 'France'] 
filter_uk  =  clean_proteins_100g[clean_proteins_100g.countries_en == 'United Kingdom']

# %%
filter_pt.duplicated(['product_name']).unique().tolist()
# Out:
# [False]

# %%
filter_es.duplicated((['product_name'])).unique().tolist()
# Out:
# [False, True]

# %%
filter_fr.duplicated((['product_name'])).unique().tolist()
# Out:
# [False, True]

# %%
filter_uk.duplicated((['product_name'])).unique().tolist()
# Out:
# [False, True]

# %%
drop_duplicates_pt = filter_pt.drop_duplicates(['product_name'])
drop_duplicates_es = filter_es.drop_duplicates(['product_name'])
drop_duplicates_fr = filter_fr.drop_duplicates(['product_name'])
drop_duplicates_uk = filter_uk.drop_duplicates(['product_name'])

# %%
#save a copy seperated
def write_csv():
    try:
        os.makedirs('../cleaned_zone')
        drop_duplicates_pt.to_csv('../cleaned_zone/foods_pt.csv',index = False,sep='\t')
        drop_duplicates_es.to_csv('../cleaned_zone/foods_es.csv',index = False,sep='\t')
        drop_duplicates_fr.to_csv('../cleaned_zone/foods_fr.csv',index = False,sep='\t')
        drop_duplicates_uk.to_csv('../cleaned_zone/foods_uk.csv',index = False,sep='\t')
        print('Save completed')
    except FileExistsError:
        drop_duplicates_pt.to_csv('../cleaned_zone/foods_pt.csv',index = False,sep='\t')
        drop_duplicates_es.to_csv('../cleaned_zone/foods_es.csv',index = False,sep='\t')
        drop_duplicates_fr.to_csv('../cleaned_zone/foods_fr.csv',index = False,sep='\t')
        drop_duplicates_uk.to_csv('../cleaned_zone/foods_uk.csv',index = False,sep='\t')
        print('Save completed')
    
try:
    os.remove('../cleaned_zone/foods_pt.csv')
    os.remove('../cleaned_zone/foods_es.csv')
    os.remove('../cleaned_zone/foods_fr.csv')
    os.remove('../cleaned_zone/foods_uk.csv')
    write_csv()
except:
    write_csv()
# Out:
# Save completed
